# %% [markdown]
# # Execise groupby, agg and merge

# %%
import pandas as pd
import numpy as np
from datetime import datetime,timedelta

# %%
# DataFrame: vendedores (5 filas)
vendedores = pd.DataFrame({
    'vendedor_id': [1, 2, 3, 4, 5],
    'nombre': ['Ana García', 'Luis Martínez', 'Carmen López', 'Pedro Sánchez', 'María Torres'],
    'region': ['Norte', 'Sur', 'Centro', 'Este', 'Oeste']
})

# DataFrame: ventas (20 filas)
np.random.seed(42)

fecha_inicio = datetime(2024, 1, 1)
fechas = [fecha_inicio + timedelta(days=int(d)) for d in np.random.randint(0, 365, 20)]

ventas = pd.DataFrame({
    'producto_id': np.random.randint(101, 111, 20),
    'cantidad':    np.random.randint(1, 50, 20),
    'fecha':       fechas,
    'vendedor_id': np.random.randint(1, 6, 20)
})
